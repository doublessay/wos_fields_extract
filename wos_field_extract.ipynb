# %%
import os
import re
import pandas as pd
from collections import Counter

# %%
path = './wos_data'
file_name_list = os.listdir(path)
file_name_list
# Out:
# ['savedrecs (1).txt',
#  'savedrecs (5).txt',
#  'savedrecs.txt',
#  'savedrecs (4).txt',
#  'savedrecs (3).txt',
#  'savedrecs (2).txt']

# %%
texts = []
for i in file_name_list:
    with open(path+'/'+i,'r') as f:
        texts.append(f.read())
        
str_texts = ' '.join(texts)

# %% [markdown]
# ### 常用字段说明
# UT 入藏号，作为文献的唯一标识，务必保留
# AU 作者简称
# AF 作者全称
# TI 文献标题
# SO 出版物名称
# DT 文献类型
# DE 作者关键词
# C1 作者地址
# RP 通讯作者地址
# FU 基金资助机构
# PY 出版年

# %%
extract_fields = ['UT','AU','TI','SO','DT','DE','C1','RP','FU','PY']

def fields_extract(fields,data = str_texts):
    
    docs = re.split('ER\n\n',data)[:-1]
    doc_num = len(docs)
    
    field_contents = []
    
    for field in fields:
        
        #全部文本匹配
        pattern = re.compile(f'\n{field} (.*?)(?=\n[^ ])',re.S) #使.包含换行符
        content = pattern.findall(data)
        
        if len(content) != doc_num:
            
            #单篇文本匹配
            content = [pattern.search(doc)[1] if pattern.search(doc) else 'Unknown' for doc in docs]
        
        #文本清洗
        if field == 'AU': #作者
            content = [re.sub('\n[ ]*',';',i) for i in content]
        
        elif field == 'TI' or field == 'DE': #题名、关键词
            content = [re.sub('\n[ ]*',' ',i) for i in content]
            
        elif field == 'C1': #作者通讯地址
            content = [re.sub('.\n[ ]*',';',i) for i in content]
        
        field_contents.append(content)
    
    field_contents_dict = dict(zip(fields,field_contents))
    df = pd.DataFrame.from_dict(field_contents_dict)
    
    #将'Unknown'替换为空值
    df.replace('Unknown',pd.NA,inplace=True)
    
    #按照年份进行排序
    if 'PY' in df.columns:
        df.sort_values(by=['PY'],inplace=True)
        
    #删除UT字段重复的数据
    if 'UT' in df.columns:
        df.drop_duplicates(subset=['UT'],ignore_index=True,inplace=True)
    
    return df
    
df = fields_extract(extract_fields)
df
# Out:
#                        UT                                                 AU  \
# 0     WOS:A1994PE63400009                              BERGEMANN, W;TOLLE, H
# 1     WOS:A1995RG55500006                                 BELAND, F;LEMAY, A
# 2     WOS:A1997BJ29H00008  Guglielmelli, E;Laschi, C;Teti, G;Fontanelli, ...
# 3     WOS:A1997BJ42X00201                        Fiorini, P;Ali, K;Seraji, H
# 4     WOS:000077035900460                    Schraft, RD;Schaeffer, C;May, T
# ...                   ...                                                ...
# 2628  WOS:000732122300001                          Do, H;Welch, KC;Sheng, WH
# 2629  WOS:000658253400001                                 Ghayvat, H;Gope, P
# 2630  WOS:000662090700001                                 Watfa, MK;Akili, A
# 2631  WOS:000677856300002       Yang, P;Bi, GS;Qi, J;Wang, XL;Yang, Y;Xu, LD
# 2632  WOS:000480906800001                             Jeyaraj, PR;Nadar, ERS
#
#                                                      TI  \
# 0     DOCUMENTATION AND COMPUTED ANALYSIS OF DATA OF...
# 1       DILEMMAS AND VALUES FOR LONG-TERM-CARE POLICIES
# 2     A modular and distributed supervisory system f...
# 3               Health care robotics: A progress report
# 4     Care-O-bot (TM): The concept of a system for a...
# ...                                                 ...
# 2628  SoHAM: A Sound-Based Human Activity Monitoring...
# 2629  Smart aging monitoring and early dementia reco...
# 2630  Factors influencing elders' intention to use a...
# 2631  Multimodal Wearable Intelligence for Dementia ...
# 2632  Smart-Monitor: Patient Monitoring System for I...
#
#                                                      SO  \
# 0                          ZEITSCHRIFT FUR GERONTOLOGIE
# 1     CANADIAN JOURNAL ON AGING-REVUE CANADIENNE DU ...
# 2     8TH INTERNATIONAL CONFERENCE ON ADVANCED ROBOT...
# 3     1997 IEEE INTERNATIONAL CONFERENCE ON ROBOTICS...
# 4     IECON '98 - PROCEEDINGS OF THE 24TH ANNUAL CON...
# ...                                                 ...
# 2628  IEEE TRANSACTIONS ON AUTOMATION SCIENCE AND EN...
# 2629                    NEURAL COMPUTING & APPLICATIONS
# 2630   INTERNATIONAL JOURNAL OF CONSTRUCTION MANAGEMENT
# 2631                      INFORMATION SYSTEMS FRONTIERS
# 2632                           IETE JOURNAL OF RESEARCH
#
#                          DT  \
# 0                   Article
# 1                   Article
# 2         Proceedings Paper
# 3         Proceedings Paper
# 4         Proceedings Paper
# ...                     ...
# 2628  Article; Early Access
# 2629  Article; Early Access
# 2630  Article; Early Access
# 2631  Article; Early Access
# 2632  Article; Early Access
#
#                                                      DE  \
# 0     DISCHARGE LETTER, COMPUTER GENERATED; ACUTE CA...
# 1     LONG-TERM CARE; FUNCTIONAL INCAPACITIES; EXPEN...
# 2                 modularity; distribution; supervision
# 3                                                  <NA>
# 4                                                  <NA>
# ...                                                 ...
# 2628  Monitoring; Hidden Markov models; Robots; Serv...
# 2629  Transfer learning; Pre-trained deep learning m...
# 2630  Elder's community; theory of planned behaviour...
# 2631  Wearable intelligence; Healthcare; Dementia; I...
# 2632  Internet of Things; Deep learning algorithm; E...
#
#                                                      C1  \
# 0                                                  <NA>
# 1                                                  <NA>
# 2                                                  <NA>
# 3                                                  <NA>
# 4     Fraunhofer Inst Prod Tech & Automatisierung, I...
# ...                                                 ...
# 2628  [Do, Ha Manh] Plume Design Inc, Palo Alto, CA ...
# 2629  [Ghayvat, Hemant] Tech Univ Denmark, Denmark F...
# 2630  [Watfa, Mohamed K.; Akili, Aya] Univ Wollongon...
# 2631  [Yang, Po] Univ Sheffield, Dept Comp Sci, Shef...
# 2632  [Jeyaraj, Pandia Rajan; Nadar, Edward Rajan Sa...
#
#                                                      RP  \
# 0     BERGEMANN, W (corresponding author), AKAD LEHR...
# 1     BELAND, F (corresponding author), UNIV MONTREA...
# 2     Guglielmelli, E (corresponding author), SCUOLA...
# 3     Fiorini, P (corresponding author), CALTECH,JET...
# 4     Schraft, RD (corresponding author), Fraunhofer...
# ...                                                 ...
# 2628  Sheng, WH (corresponding author), Oklahoma Sta...
# 2629  Ghayvat, H (corresponding author), Tech Univ D...
# 2630  Watfa, MK (corresponding author), Univ Wollong...
# 2631  Yang, P (corresponding author), Univ Sheffield...
# 2632  Jeyaraj, PR (corresponding author), Mepco Schl...
#
#                                                      FU    PY
# 0                                                  <NA>  1994
# 1                                                  <NA>  1995
# 2                                                  <NA>  1997
# 3                                                  <NA>  1997
# 4                                                  <NA>  1998
# ...                                                 ...   ...
# 2628  National Science Foundation (NSF)National Scie...  <NA>
# 2629                                Linnaeus University  <NA>
# 2630                                               <NA>  <NA>
# 2631  Yunnan University's Research Innovation Fund f...  <NA>
# 2632         Indian National Science Academy, New Delhi  <NA>
#
# [2633 rows x 10 columns]

# %%
df.to_excel('wos_extract_fields_result.xlsx',index=True)
